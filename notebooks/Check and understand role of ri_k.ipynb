# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load</a></span></li></ul></div>

# %% [markdown]
# # Conclusion

# %% [markdown]
# I did this notebook I think to understand the role of bumps /no bumps on the ri oscillations but did not really analyze it...

# %% [markdown]
# **short story**: we have tried to smooth out the rebalancers from one iteration to the next but currently, not really successful.

# %% [markdown]
# This is very important because when we solve the problem "perfectly" we actually cause problems in the rebalancing update... to understand!!

# %% [markdown]
# # Load

# %%
# %load_ext autoreload
# %autoreload 2
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os

from amod_ed.result_analysis import plot_ri, print_final_flows, plot_cost_all_path, plot_ri_list, plot_balance_list

import pandas as pd

from amod_ed.result_analysis import plot_stop_and_cost
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
subfolder='results_withBumps'
subfolder2='results'
subfolder3='conditional_ri_smoothing_no_bumps'

# %%
n_nodes=25

# %%
path='Data/'+str(n_nodes)+'Nodes/outputs/quals/'+subfolder
path2='Data/'+str(n_nodes)+'Nodes/outputs/quals/'+subfolder2
path3='Data/'+str(n_nodes)+'Nodes/outputs/quals/'+subfolder3

# %%
print(os.listdir(path))
# Out:
# ['output_L_10000_ni_1000_no_20_ev_0_relative_progress_fu_False.pkl']

# %%
filename=os.listdir(path)[0]
print(filename)

with open(os.path.join(path, filename), 'rb') as f:
        G_FW, OD, ri_FW1, n_outer, n_inner, balance, opt_res, OD_list, balance_list = pickle.load(f)
# Out:
# output_L_10000_ni_1000_no_20_ev_0_relative_progress_fu_False.pkl

# %%
print(os.listdir(path2))
# Out:
# ['output_L_10000_ni_1000_no_20_ev_0_relative_progress_fu_True.pkl', 'output_L_10000_ni_5000_no_40_ev_0_relative_progress_fu_True.pkl', 'output_L_10000_ni_1000_no_30_ev_0_relative_progress_fu_True.pkl']

# %%
filename=os.listdir(path2)[0]
print(filename)

with open(os.path.join(path2, filename), 'rb') as f:
        G_FW, OD, ri_FW2, n_outer, n_inner, balance, opt_res, OD_list, balance_list = pickle.load(f)
# Out:
# output_L_10000_ni_1000_no_20_ev_0_relative_progress_fu_True.pkl
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-641e65a56bc8> in <module>
#       3
#       4 with open(os.path.join(path2, filename), 'rb') as f:
# ----> 5         G_FW, OD, ri_FW2, n_outer, n_inner, balance, opt_res, OD_list, balance_list = pickle.load(f)
#
# ValueError: too many values to unpack (expected 9)

# %%
from result_analysis import plot_ri_list, compare_ri

# %% [markdown]
# I think this is for the no bumps (no uf): we see the ri stabilizing over time.

# %%
plot_ri_list(ri_FW1)

# %%
plot_ri_list(ri_FW2)

# %%
compare_ri(ri_FW1, ri_FW2, '1')

# %% [markdown]
# This one is with conditional ri smoothing

# %%
print(os.listdir(path3))
# Out:
# ['output_L_10000_ni_1000_no_20_ev_0_relative_progress_fu_True.pkl']

# %%
filename=os.listdir(path3)[0]
print(filename)

with open(os.path.join(path3, filename), 'rb') as f:
        G_FW, OD, ri_FW3, n_outer, n_inner, balance, opt_res, OD_list, balance_list, params = pickle.load(f)
# Out:
# output_L_10000_ni_1000_no_20_ev_0_relative_progress_fu_True.pkl

# %%
plot_ri_list(ri_FW3)

# %%
compare_ri(ri_FW1, ri_FW3, '9')
