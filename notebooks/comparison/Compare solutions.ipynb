# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#load" data-toc-modified-id="load-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>load</a></span></li></ul></div>

# %% [markdown]
# # Description

# %% [markdown]
# This notebook should enable us to compare solutions between
# - black box solver, from several initializations
# - the other solver, for different values of L

# %% [markdown]
# We want to compare:
# - the values of the flows at the end of the solution
# - The norm of the difference
# - The time it takes to compute

# %%
path='/Users/lucasfuentes/icu/notebooks/Data_comparison/3Nodes'

# %% [markdown]
# # load

# %%
import pickle
import os

# %%
with open(os.path.join(path,'sols_bb.pkl'), 'rb') as f:
    r_tot_bb, nodes, f_p_tot = pickle.load(f)

# %%
path_icu=os.path.join(path, 'outputs', 'Li_comparison_ni_5000')

# %%
print(os.listdir(path_icu))
# Out:
# ['output_L_100_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl', 'output_L_1000000_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl', 'output_L_100000_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl', 'output_L_1000_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl', 'output_L_10_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl', 'output_L_10000000_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl', 'output_L_10000_ni_5000_no_50_ev_0_relative_progress_fu_False.pkl']

# %%
fnm=os.listdir(path_icu)[0]

# %%
with open(os.path.join(path_icu, fnm), 'rb') as f:
        G_FW, OD, ri_FW, n_outer, n_inner, balance, opt_res, OD_list, balance_list, params = pickle.load(f)

# %% [markdown]
# ...

# %%
from amod_ed.result_analysis import plot_ri_list

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
ri=np.array(r_tot_bb[0])
for i in range(ri.shape[1]):
    plt.plot(ri[:,i], '--')
plt.grid()

# %%
plot_ri_list(ri_FW)
